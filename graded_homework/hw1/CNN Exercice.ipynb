# %% [markdown]
# ## Convolutional Networks
#
# We'll check out how to build a **convolutional network** to classify CIFAR10 images. By using weight sharing - multiple units with the same weights - convolutional layers are able to learn repeated patterns in your data. For example, a unit could learn the pattern for an eye, or a face, or lower level features like edges.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import time

import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
import torch.utils.data as utils
from torchvision import datasets, transforms
from torch.utils.data.sampler import SubsetRandomSampler
import matplotlib.pyplot as plt
import torchvision.utils as vutils
from torchvision.datasets import CIFAR10

# %matplotlib inline

# %%
label_names = [
    'airplane',
    'automobile',
    'bird',
    'cat',
    'deer',
    'dog',
    'frog',
    'horse',
    'ship',
    'truck'
]


def plot_images(images, cls_true, cls_pred=None):
    """
    Adapted from https://github.com/Hvass-Labs/TensorFlow-Tutorials/
    """
    fig, axes = plt.subplots(3, 3)

    for i, ax in enumerate(axes.flat):
        # plot img
        ax.imshow(images[i, :, :, :], interpolation='spline16')

        # show true & predicted classes
        cls_true_name = label_names[cls_true[i]]
        if cls_pred is None:
            xlabel = "{0} ({1})".format(cls_true_name, cls_true[i])
        else:
            cls_pred_name = label_names[cls_pred[i]]
            xlabel = "True: {0}\nPred: {1}".format(
                cls_true_name, cls_pred_name
            )
        ax.set_xlabel(xlabel)
        ax.set_xticks([])
        ax.set_yticks([])

    plt.show()

# %%
def get_train_valid_loader(data_dir='data',
                           batch_size=64,
                           augment=False,
                           random_seed=1,
                           valid_size=0.02,
                           shuffle=True,
                           show_sample=True,
                           num_workers=4,
                           pin_memory=False):
    """
    Utility function for loading and returning train and valid
    multi-process iterators over the CIFAR-10 dataset. A sample
    9x9 grid of the images can be optionally displayed.
    If using CUDA, num_workers should be set to 1 and pin_memory to True.
    Params
    ------
    - data_dir: path directory to the dataset.
    - batch_size: how many samples per batch to load.
    - augment: whether to apply the data augmentation scheme
      mentioned in the paper. Only applied on the train split.
    - random_seed: fix seed for reproducibility.
    - valid_size: percentage split of the training set used for
      the validation set. Should be a float in the range [0, 1].
    - shuffle: whether to shuffle the train/validation indices.
    - show_sample: plot 9x9 sample grid of the dataset.
    - num_workers: number of subprocesses to use when loading the dataset.
    - pin_memory: whether to copy tensors into CUDA pinned memory. Set it to
      True if using GPU.
    Returns
    -------
    - train_loader: training set iterator.
    - valid_loader: validation set iterator.
    """
    error_msg = "[!] valid_size should be in the range [0, 1]."
    assert ((valid_size >= 0) and (valid_size <= 1)), error_msg

    normalize = transforms.Normalize(
        mean=[0.4914, 0.4822, 0.4465],
        std=[0.2023, 0.1994, 0.2010],
    )

    # define transforms for validation (no augmentation)
    valid_transform = transforms.Compose([
        transforms.ToTensor(),
        normalize,
    ])

    # Define the transform for training (and data augmentation)

    train_transform = transforms.Compose([
        transforms.ToTensor(),
        normalize,
    ])

    # load the dataset
    train_dataset = datasets.CIFAR10(
        root=data_dir, train=True,
        download=True, transform=train_transform,
    )

    valid_dataset = datasets.CIFAR10(
        root=data_dir, train=True,
        download=True, transform=valid_transform,
    )

    num_train = len(train_dataset)
    indices = list(range(num_train))
    split = int(np.floor(valid_size * num_train))

    if shuffle:
        np.random.seed(random_seed)
        np.random.shuffle(indices)

    train_idx, valid_idx = indices[split:], indices[:split]
    train_sampler = SubsetRandomSampler(train_idx)
    valid_sampler = SubsetRandomSampler(valid_idx)

    train_loader = torch.utils.data.DataLoader(
        train_dataset, batch_size=batch_size, sampler=train_sampler,
        num_workers=num_workers, pin_memory=pin_memory,
    )
    valid_loader = torch.utils.data.DataLoader(
        valid_dataset, batch_size=batch_size, sampler=valid_sampler,
        num_workers=num_workers, pin_memory=pin_memory,
    )

    # visualize some images if requested
    if show_sample:
        sample_loader = torch.utils.data.DataLoader(
            train_dataset, batch_size=9, shuffle=shuffle,
            num_workers=num_workers, pin_memory=pin_memory,
        )
        data_iter = iter(sample_loader)
        images, labels = next(data_iter)
        # Unnormalize the images for display
        mean = [0.4914, 0.4822, 0.4465]
        std = [0.2023, 0.1994, 0.2010]
        unnorm_images = [unnormalize(img, mean, std) for img in images]
        X = torch.stack(unnorm_images).numpy().transpose([0, 2, 3, 1])
        plot_images(X, labels)

    return (train_loader, valid_loader)

def unnormalize(img, mean, std):
    img = img * torch.tensor(std).view(3, 1, 1) + torch.tensor(mean).view(3, 1, 1)
    return img

trainloader, valloader = get_train_valid_loader()
# Out:
# 100%|██████████| 170M/170M [00:03<00:00, 49.1MB/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:432: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.9802322e-08..0.9764706].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.9802322e-08..0.84313726].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.9802322e-08..0.7411765].

# %% [markdown]
# # Convolutional Neural Network Architecture

# %% [markdown]
# Let's first talk about the overall architecture of a CNN and how each dimension evolves after each layer, we'll take as example the first and famous CNN LeNet5 :
# <figure align="center">
#   <img src="https://doimages.nyc3.cdn.digitaloceanspaces.com/010AI-ML/content/images/2021/10/image-17.png" alt="LeNet5 Architecture" width="600">
#   <figcaption>Image credit: <a href="https://en.wikipedia.org">Wikipedia</a></figcaption>
# </figure>

# %% [markdown]
# For that, we will have some quick questions to see if you understand what happens during training/inference:
#
# ### 1. First Layer Convolution
#
# If we consider the input of LeNet5 to be CIFAR-10, what would be the shape of the parameters of the first convolutional layer (stride = 1)?
#
# - **A.** `torch.Size([6, 1, 5, 5])`
# - **B.** `torch.Size([6, 3, 3, 3])`
# - **C.** `torch.Size([6, 1, 5, 5])`
# - **D.** `torch.Size([6, 3, 5, 5])`
#
# It's the response D
#
# ---
#
# ### 2. Subsampling Window
#
# What is the shape of the subsampling window (stride = 2) for the second layer (between C1 and C2), and does this shape remain invariant regardless of the subsampling method (e.g., Avg pooling or Max pooling)?
#
# - **A.** `2x2, yes it does`
# - **B.** `3x3, no it doesn't`
# - **C.** `2x2, no it doesn't`
# - **D.** `yes, it does`
#
# It's the response A
#
# ---
#
# ### 3. Backpropagation for Convolutional Filters
#
# Do the filters in the convolutional layers also benefit from backpropagation?
#
# Yes
#
# ---
#
# ### 4. Role of the Fully-Connected Layer
#
# Explain in your own words why it is necessary to have a fully-connected layer in the architecture.
#
# The CNN layer is use to extract features, so at some point we need a fully-connected layer to be able to take a decision based on these features
#
# ---
#
# If you had any struggle to answer one of theses questions, feel free to ask a TA about intuition or hints about the solution.

# %% [markdown]
# # Build your own Convolutional Neural Network Architecture

# %% [markdown]
# ## Different ways to improve the accuracy of your network :
# - Change the number of convolutions and layers (you can take inspiration from internet as you as you cite the architecture)
# - Change the optmizer / its hyperparameters
# - Add new types of layers
# - Do some data augmentation in the get_train_valid_loader function (flipped, cropped, uncentered images) cf. https://pytorch.org/vision/stable/transforms.html

# %%
class ConvNet(nn.Module):
    def __init__(self, n_input_channels=3, n_output=10):
        super().__init__()
        ################################################################################
        # TODO:                                                                        #
        # Define 2 or more different layers of the neural network                      #
        ################################################################################
        self.features = nn.Sequential(

            nn.Conv2d(n_input_channels, 32, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),

        )

        self.classifier = nn.Sequential(

            nn.Linear(128 * 4 * 4, 256),
            nn.ReLU(),
            nn.Dropout(0.5),

            nn.Linear(256, n_output)

        )
        ################################################################################
        #                              END OF YOUR CODE                                #
        ################################################################################

    def forward(self, x):
        ################################################################################
        # TODO:                                                                        #
        # Set up the forward pass that the input data will go through.                 #
        # A good activation function betweent the layers is a ReLu function.           #
        #                                                                              #
        # Note that the output of the last convolution layer should be flattened       #
        # before being inputted to the fully connected layer. We can flatten           #
        # Tensor `x` with `x.view`.                                                    #
        ################################################################################
        x = self.features(x)

        x = x.view(x.size(0), -1)

        x = self.classifier(x)
        ################################################################################
        #                              END OF YOUR CODE                                #
        ################################################################################

        return x

    def predict(self, x):
        logits = self.forward(x)
        return F.softmax(logits)

# %%
net = ConvNet()
################################################################################
# TODO:                                                                        #
# Choose an Optimizer that will be used to minimize the loss function.         #
# Choose a critera that measures the loss                                      #
################################################################################
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(net.parameters(), lr=0.0003)

epochs = 5
steps = 0
running_loss = 0
print_every = 20
for e in range(epochs):
    start = time.time()
    for images, labels in iter(trainloader):

        steps += 1
        ################################################################################
        # TODO:                                                                        #
        # Run the training process                                                     #
        #                                                                              #
        #                                                                              #
        ################################################################################
        targets = labels

        optimizer.zero_grad()

        output = net(images)
        ################################################################################
        #                              END OF YOUR CODE                                #
        ################################################################################

        loss = criterion(output, targets)
        ################################################################################
        # TODO:                                                                        #
        # Run the training process                                                     #
        #                                                                              #
        # HINT: Calculate the gradient and move one step further                       #
        ################################################################################
        loss.backward()
        optimizer.step()
        ################################################################################
        #                              END OF YOUR CODE                                #
        ################################################################################

        running_loss += loss.item()

        if steps % print_every == 0:
            stop = time.time()
            # Test accuracy
            accuracy = 0
            for ii, (images, labels) in enumerate(valloader):

                ################################################################################
                # TODO:                                                                        #
                # Calculate the accuracy                                                       #
                ################################################################################
                with torch.no_grad():

                  outputs = net(images)

                  _, preds = torch.max(outputs, 1)

                  acc = torch.mean((preds == labels).float())

                  accuracy += acc
                ################################################################################
                #                              END OF YOUR CODE                                #
                ################################################################################

            print("Epoch: {}/{}..".format(e+1, epochs),
                  "Loss: {:.4f}..".format(running_loss/print_every),
                  "Test accuracy: {:.4f}..".format(accuracy/(ii+1)),
                  "{:.4f} s/batch".format((stop - start)/print_every)
                 )
            running_loss = 0
            start = time.time()
# Out:
# Epoch: 1/5.. Loss: 2.2622.. Test accuracy: 0.1801.. 0.1368 s/batch
# Epoch: 1/5.. Loss: 2.1279.. Test accuracy: 0.2381.. 0.1103 s/batch
# Epoch: 1/5.. Loss: 2.0605.. Test accuracy: 0.2971.. 0.1098 s/batch
# Epoch: 1/5.. Loss: 1.9593.. Test accuracy: 0.3115.. 0.1666 s/batch
# Epoch: 1/5.. Loss: 1.8904.. Test accuracy: 0.3240.. 0.1103 s/batch
# Epoch: 1/5.. Loss: 1.7807.. Test accuracy: 0.3291.. 0.1103 s/batch
# Epoch: 1/5.. Loss: 1.8428.. Test accuracy: 0.3139.. 0.1110 s/batch
# Epoch: 1/5.. Loss: 1.7778.. Test accuracy: 0.3459.. 0.1774 s/batch
# Epoch: 1/5.. Loss: 1.7813.. Test accuracy: 0.3824.. 0.1119 s/batch
# Epoch: 1/5.. Loss: 1.7881.. Test accuracy: 0.3826.. 0.1115 s/batch
# Epoch: 1/5.. Loss: 1.6795.. Test accuracy: 0.3857.. 0.1127 s/batch
# Epoch: 1/5.. Loss: 1.6275.. Test accuracy: 0.4094.. 0.1705 s/batch
# Epoch: 1/5.. Loss: 1.6150.. Test accuracy: 0.4105.. 0.1104 s/batch
# Epoch: 1/5.. Loss: 1.6456.. Test accuracy: 0.4133.. 0.1268 s/batch
# Epoch: 1/5.. Loss: 1.5700.. Test accuracy: 0.4096.. 0.1289 s/batch
# Epoch: 1/5.. Loss: 1.5629.. Test accuracy: 0.4230.. 0.1313 s/batch
# Epoch: 1/5.. Loss: 1.5720.. Test accuracy: 0.4299.. 0.1143 s/batch
# Epoch: 1/5.. Loss: 1.5369.. Test accuracy: 0.4521.. 0.1116 s/batch
# Epoch: 1/5.. Loss: 1.5258.. Test accuracy: 0.4449.. 0.1707 s/batch
# Epoch: 1/5.. Loss: 1.5479.. Test accuracy: 0.4580.. 0.1096 s/batch
# Epoch: 1/5.. Loss: 1.4779.. Test accuracy: 0.4414.. 0.1127 s/batch
# Epoch: 1/5.. Loss: 1.5068.. Test accuracy: 0.4615.. 0.1355 s/batch
# Epoch: 1/5.. Loss: 1.4849.. Test accuracy: 0.4559.. 0.1718 s/batch
# Epoch: 1/5.. Loss: 1.4337.. Test accuracy: 0.4783.. 0.1155 s/batch
# Epoch: 1/5.. Loss: 1.4710.. Test accuracy: 0.4871.. 0.1106 s/batch
# Epoch: 1/5.. Loss: 1.4384.. Test accuracy: 0.4437.. 0.1178 s/batch
# Epoch: 1/5.. Loss: 1.4405.. Test accuracy: 0.4992.. 0.1541 s/batch
# Epoch: 1/5.. Loss: 1.3919.. Test accuracy: 0.4865.. 0.1124 s/batch
# Epoch: 1/5.. Loss: 1.4051.. Test accuracy: 0.4668.. 0.1095 s/batch
# Epoch: 1/5.. Loss: 1.4502.. Test accuracy: 0.4910.. 0.1290 s/batch
# Epoch: 1/5.. Loss: 1.3416.. Test accuracy: 0.4832.. 0.1390 s/batch
# Epoch: 1/5.. Loss: 1.4115.. Test accuracy: 0.4939.. 0.1100 s/batch
# Epoch: 1/5.. Loss: 1.3305.. Test accuracy: 0.5076.. 0.1113 s/batch
# Epoch: 1/5.. Loss: 1.4247.. Test accuracy: 0.5133.. 0.1524 s/batch
# Epoch: 1/5.. Loss: 1.3863.. Test accuracy: 0.5084.. 0.1194 s/batch
# Epoch: 1/5.. Loss: 1.3923.. Test accuracy: 0.5061.. 0.1116 s/batch
# Epoch: 1/5.. Loss: 1.3610.. Test accuracy: 0.5186.. 0.1146 s/batch
# Epoch: 1/5.. Loss: 1.4124.. Test accuracy: 0.5209.. 0.1649 s/batch
# Epoch: 2/5.. Loss: 1.3483.. Test accuracy: 0.5143.. 0.0906 s/batch
# Epoch: 2/5.. Loss: 1.3138.. Test accuracy: 0.5201.. 0.1143 s/batch
# Epoch: 2/5.. Loss: 1.2729.. Test accuracy: 0.5215.. 0.1125 s/batch
# Epoch: 2/5.. Loss: 1.3126.. Test accuracy: 0.5277.. 0.1720 s/batch
# Epoch: 2/5.. Loss: 1.2755.. Test accuracy: 0.5275.. 0.1149 s/batch
# Epoch: 2/5.. Loss: 1.2565.. Test accuracy: 0.5410.. 0.1134 s/batch
# Epoch: 2/5.. Loss: 1.2831.. Test accuracy: 0.5318.. 0.1221 s/batch
# Epoch: 2/5.. Loss: 1.2874.. Test accuracy: 0.5369.. 0.1553 s/batch
# Epoch: 2/5.. Loss: 1.2712.. Test accuracy: 0.5479.. 0.1135 s/batch
# Epoch: 2/5.. Loss: 1.2971.. Test accuracy: 0.5260.. 0.1153 s/batch
# Epoch: 2/5.. Loss: 1.2755.. Test accuracy: 0.5514.. 0.1436 s/batch
# Epoch: 2/5.. Loss: 1.3263.. Test accuracy: 0.5516.. 0.1334 s/batch
# Epoch: 2/5.. Loss: 1.2176.. Test accuracy: 0.5492.. 0.1167 s/batch
# Epoch: 2/5.. Loss: 1.2451.. Test accuracy: 0.5488.. 0.1112 s/batch
# Epoch: 2/5.. Loss: 1.2917.. Test accuracy: 0.5588.. 0.1617 s/batch
# Epoch: 2/5.. Loss: 1.2049.. Test accuracy: 0.5244.. 0.1128 s/batch
# Epoch: 2/5.. Loss: 1.1939.. Test accuracy: 0.5592.. 0.1150 s/batch
# Epoch: 2/5.. Loss: 1.2539.. Test accuracy: 0.5527.. 0.1132 s/batch
# Epoch: 2/5.. Loss: 1.1817.. Test accuracy: 0.5521.. 0.1795 s/batch
# Epoch: 2/5.. Loss: 1.2426.. Test accuracy: 0.5432.. 0.1136 s/batch
# Epoch: 2/5.. Loss: 1.2089.. Test accuracy: 0.5418.. 0.1144 s/batch
# Epoch: 2/5.. Loss: 1.2275.. Test accuracy: 0.5617.. 0.1160 s/batch
# Epoch: 2/5.. Loss: 1.1986.. Test accuracy: 0.5891.. 0.1710 s/batch
# Epoch: 2/5.. Loss: 1.1594.. Test accuracy: 0.5740.. 0.1139 s/batch
# Epoch: 2/5.. Loss: 1.1453.. Test accuracy: 0.5748.. 0.1128 s/batch
# Epoch: 2/5.. Loss: 1.2009.. Test accuracy: 0.5709.. 0.1240 s/batch
# Epoch: 2/5.. Loss: 1.2131.. Test accuracy: 0.5707.. 0.1551 s/batch
# Epoch: 2/5.. Loss: 1.2098.. Test accuracy: 0.5586.. 0.1128 s/batch
# Epoch: 2/5.. Loss: 1.1878.. Test accuracy: 0.5787.. 0.1156 s/batch
# Epoch: 2/5.. Loss: 1.1299.. Test accuracy: 0.6053.. 0.1395 s/batch
# Epoch: 2/5.. Loss: 1.2882.. Test accuracy: 0.5818.. 0.1358 s/batch
# Epoch: 2/5.. Loss: 1.1255.. Test accuracy: 0.5711.. 0.1162 s/batch
# Epoch: 2/5.. Loss: 1.1386.. Test accuracy: 0.5859.. 0.1119 s/batch
# Epoch: 2/5.. Loss: 1.1428.. Test accuracy: 0.5699.. 0.1593 s/batch
# Epoch: 2/5.. Loss: 1.2005.. Test accuracy: 0.5889.. 0.1105 s/batch
# Epoch: 2/5.. Loss: 1.1516.. Test accuracy: 0.5875.. 0.1103 s/batch
# Epoch: 2/5.. Loss: 1.1707.. Test accuracy: 0.6041.. 0.1114 s/batch
# Epoch: 2/5.. Loss: 1.1551.. Test accuracy: 0.5988.. 0.1668 s/batch
# Epoch: 3/5.. Loss: 1.1430.. Test accuracy: 0.5822.. 0.0587 s/batch
# Epoch: 3/5.. Loss: 1.1412.. Test accuracy: 0.5883.. 0.1140 s/batch
# Epoch: 3/5.. Loss: 1.1097.. Test accuracy: 0.6145.. 0.1119 s/batch
# Epoch: 3/5.. Loss: 1.0698.. Test accuracy: 0.5934.. 0.1756 s/batch
# Epoch: 3/5.. Loss: 1.1076.. Test accuracy: 0.6109.. 0.1113 s/batch
# Epoch: 3/5.. Loss: 1.0666.. Test accuracy: 0.5818.. 0.1123 s/batch
# Epoch: 3/5.. Loss: 1.0629.. Test accuracy: 0.5957.. 0.1075 s/batch
# Epoch: 3/5.. Loss: 1.0938.. Test accuracy: 0.6109.. 0.1549 s/batch
# Epoch: 3/5.. Loss: 1.0584.. Test accuracy: 0.6180.. 0.1078 s/batch
# Epoch: 3/5.. Loss: 1.0367.. Test accuracy: 0.6109.. 0.1117 s/batch
# Epoch: 3/5.. Loss: 1.0928.. Test accuracy: 0.6094.. 0.1162 s/batch
# Epoch: 3/5.. Loss: 1.0825.. Test accuracy: 0.6035.. 0.1538 s/batch
# Epoch: 3/5.. Loss: 1.0350.. Test accuracy: 0.6008.. 0.1120 s/batch
# Epoch: 3/5.. Loss: 1.0297.. Test accuracy: 0.6018.. 0.1076 s/batch
# Epoch: 3/5.. Loss: 1.1096.. Test accuracy: 0.6232.. 0.1212 s/batch
# Epoch: 3/5.. Loss: 1.0663.. Test accuracy: 0.6191.. 0.1468 s/batch
# Epoch: 3/5.. Loss: 1.0296.. Test accuracy: 0.6211.. 0.1206 s/batch
# Epoch: 3/5.. Loss: 1.0306.. Test accuracy: 0.6174.. 0.1141 s/batch
# Epoch: 3/5.. Loss: 0.9919.. Test accuracy: 0.6326.. 0.1411 s/batch
# Epoch: 3/5.. Loss: 1.0131.. Test accuracy: 0.6094.. 0.1292 s/batch
# Epoch: 3/5.. Loss: 1.0170.. Test accuracy: 0.6055.. 0.1218 s/batch
# Epoch: 3/5.. Loss: 1.0419.. Test accuracy: 0.5961.. 0.1105 s/batch
# Epoch: 3/5.. Loss: 1.0988.. Test accuracy: 0.6143.. 0.1662 s/batch
# Epoch: 3/5.. Loss: 1.0335.. Test accuracy: 0.6172.. 0.1158 s/batch
# Epoch: 3/5.. Loss: 1.0481.. Test accuracy: 0.6275.. 0.1081 s/batch
# Epoch: 3/5.. Loss: 0.9972.. Test accuracy: 0.6238.. 0.1083 s/batch
# Epoch: 3/5.. Loss: 1.0347.. Test accuracy: 0.6057.. 0.1746 s/batch
# Epoch: 3/5.. Loss: 1.0663.. Test accuracy: 0.6436.. 0.1133 s/batch
# Epoch: 3/5.. Loss: 1.0093.. Test accuracy: 0.6121.. 0.1159 s/batch
# Epoch: 3/5.. Loss: 1.0291.. Test accuracy: 0.6191.. 0.1142 s/batch
# Epoch: 3/5.. Loss: 1.0280.. Test accuracy: 0.6213.. 0.1794 s/batch
# Epoch: 3/5.. Loss: 1.0242.. Test accuracy: 0.6148.. 0.1169 s/batch
# Epoch: 3/5.. Loss: 1.1154.. Test accuracy: 0.6406.. 0.1142 s/batch
# Epoch: 3/5.. Loss: 1.0232.. Test accuracy: 0.6271.. 0.1257 s/batch
# Epoch: 3/5.. Loss: 0.9803.. Test accuracy: 0.6363.. 0.1515 s/batch
# Epoch: 3/5.. Loss: 0.9978.. Test accuracy: 0.6422.. 0.1123 s/batch
# Epoch: 3/5.. Loss: 0.9980.. Test accuracy: 0.6398.. 0.1213 s/batch
# Epoch: 3/5.. Loss: 1.0187.. Test accuracy: 0.6213.. 0.1420 s/batch
# Epoch: 4/5.. Loss: 1.0563.. Test accuracy: 0.6379.. 0.0236 s/batch
# Epoch: 4/5.. Loss: 0.9395.. Test accuracy: 0.6486.. 0.1110 s/batch
# Epoch: 4/5.. Loss: 0.9659.. Test accuracy: 0.6400.. 0.1119 s/batch
# Epoch: 4/5.. Loss: 0.9648.. Test accuracy: 0.6555.. 0.1620 s/batch
# Epoch: 4/5.. Loss: 0.9892.. Test accuracy: 0.6555.. 0.1106 s/batch
# Epoch: 4/5.. Loss: 0.9589.. Test accuracy: 0.6348.. 0.1138 s/batch
# Epoch: 4/5.. Loss: 1.0044.. Test accuracy: 0.6295.. 0.1174 s/batch
# Epoch: 4/5.. Loss: 0.9506.. Test accuracy: 0.6422.. 0.1739 s/batch
# Epoch: 4/5.. Loss: 1.0057.. Test accuracy: 0.6416.. 0.1153 s/batch
# Epoch: 4/5.. Loss: 0.9773.. Test accuracy: 0.6395.. 0.1123 s/batch
# Epoch: 4/5.. Loss: 1.0320.. Test accuracy: 0.6303.. 0.1092 s/batch
# Epoch: 4/5.. Loss: 1.0127.. Test accuracy: 0.6396.. 0.1709 s/batch
# Epoch: 4/5.. Loss: 0.9865.. Test accuracy: 0.6510.. 0.1122 s/batch
# Epoch: 4/5.. Loss: 0.9541.. Test accuracy: 0.6438.. 0.1111 s/batch
# Epoch: 4/5.. Loss: 0.8850.. Test accuracy: 0.6602.. 0.1170 s/batch
# Epoch: 4/5.. Loss: 0.9950.. Test accuracy: 0.6418.. 0.1627 s/batch
# Epoch: 4/5.. Loss: 0.9055.. Test accuracy: 0.6332.. 0.1117 s/batch
# Epoch: 4/5.. Loss: 0.9278.. Test accuracy: 0.6562.. 0.1107 s/batch
# Epoch: 4/5.. Loss: 0.9611.. Test accuracy: 0.6498.. 0.1283 s/batch
# Epoch: 4/5.. Loss: 0.9696.. Test accuracy: 0.6439.. 0.1463 s/batch
# Epoch: 4/5.. Loss: 0.8966.. Test accuracy: 0.6289.. 0.1092 s/batch
# Epoch: 4/5.. Loss: 0.9712.. Test accuracy: 0.6518.. 0.1129 s/batch
# Epoch: 4/5.. Loss: 0.8747.. Test accuracy: 0.6434.. 0.1473 s/batch
# Epoch: 4/5.. Loss: 0.9510.. Test accuracy: 0.6545.. 0.1295 s/batch
# Epoch: 4/5.. Loss: 0.9621.. Test accuracy: 0.6562.. 0.1131 s/batch
# Epoch: 4/5.. Loss: 0.8900.. Test accuracy: 0.6578.. 0.1135 s/batch
# Epoch: 4/5.. Loss: 0.9253.. Test accuracy: 0.6539.. 0.1508 s/batch
# Epoch: 4/5.. Loss: 0.9560.. Test accuracy: 0.6566.. 0.1171 s/batch
# Epoch: 4/5.. Loss: 0.8996.. Test accuracy: 0.6568.. 0.1132 s/batch
# Epoch: 4/5.. Loss: 0.8897.. Test accuracy: 0.6537.. 0.1108 s/batch
# Epoch: 4/5.. Loss: 0.8926.. Test accuracy: 0.6514.. 0.1668 s/batch
# Epoch: 4/5.. Loss: 0.9136.. Test accuracy: 0.6578.. 0.1117 s/batch
# Epoch: 4/5.. Loss: 0.9179.. Test accuracy: 0.6459.. 0.1094 s/batch
# Epoch: 4/5.. Loss: 0.8565.. Test accuracy: 0.6520.. 0.1129 s/batch
# Epoch: 4/5.. Loss: 0.9277.. Test accuracy: 0.6578.. 0.1716 s/batch
# Epoch: 4/5.. Loss: 0.9038.. Test accuracy: 0.6518.. 0.1107 s/batch
# Epoch: 4/5.. Loss: 0.8955.. Test accuracy: 0.6672.. 0.1143 s/batch
# Epoch: 4/5.. Loss: 0.9646.. Test accuracy: 0.6582.. 0.1117 s/batch
# Epoch: 4/5.. Loss: 0.9070.. Test accuracy: 0.6654.. 0.1778 s/batch
# Epoch: 5/5.. Loss: 0.8586.. Test accuracy: 0.6537.. 0.1096 s/batch
# Epoch: 5/5.. Loss: 0.8603.. Test accuracy: 0.6754.. 0.1120 s/batch
# Epoch: 5/5.. Loss: 0.8690.. Test accuracy: 0.6652.. 0.1228 s/batch
# Epoch: 5/5.. Loss: 0.8683.. Test accuracy: 0.6404.. 0.1487 s/batch
# Epoch: 5/5.. Loss: 0.8568.. Test accuracy: 0.6506.. 0.1135 s/batch
# Epoch: 5/5.. Loss: 0.9128.. Test accuracy: 0.6646.. 0.1106 s/batch
# Epoch: 5/5.. Loss: 0.8623.. Test accuracy: 0.6580.. 0.1315 s/batch
# Epoch: 5/5.. Loss: 0.8678.. Test accuracy: 0.6604.. 0.1389 s/batch
# Epoch: 5/5.. Loss: 0.8757.. Test accuracy: 0.6709.. 0.1138 s/batch
# Epoch: 5/5.. Loss: 0.8431.. Test accuracy: 0.6732.. 0.1136 s/batch
# Epoch: 5/5.. Loss: 0.8905.. Test accuracy: 0.6699.. 0.1478 s/batch
# Epoch: 5/5.. Loss: 0.8598.. Test accuracy: 0.6686.. 0.1205 s/batch
# Epoch: 5/5.. Loss: 0.8361.. Test accuracy: 0.6744.. 0.1148 s/batch
# Epoch: 5/5.. Loss: 0.8638.. Test accuracy: 0.6609.. 0.1146 s/batch
# Epoch: 5/5.. Loss: 0.9281.. Test accuracy: 0.6781.. 0.1782 s/batch
# Epoch: 5/5.. Loss: 0.8351.. Test accuracy: 0.6756.. 0.1155 s/batch
# Epoch: 5/5.. Loss: 0.8797.. Test accuracy: 0.6650.. 0.1145 s/batch
# Epoch: 5/5.. Loss: 0.8558.. Test accuracy: 0.6727.. 0.1114 s/batch
# Epoch: 5/5.. Loss: 0.8450.. Test accuracy: 0.6576.. 0.1775 s/batch
# Epoch: 5/5.. Loss: 0.8014.. Test accuracy: 0.6789.. 0.1116 s/batch
# Epoch: 5/5.. Loss: 0.8511.. Test accuracy: 0.6617.. 0.1135 s/batch
# Epoch: 5/5.. Loss: 0.8503.. Test accuracy: 0.6811.. 0.1189 s/batch
# Epoch: 5/5.. Loss: 0.8429.. Test accuracy: 0.6598.. 0.1548 s/batch
# Epoch: 5/5.. Loss: 0.8236.. Test accuracy: 0.6666.. 0.1162 s/batch
# Epoch: 5/5.. Loss: 0.8406.. Test accuracy: 0.6783.. 0.1148 s/batch
# Epoch: 5/5.. Loss: 0.8713.. Test accuracy: 0.6459.. 0.1486 s/batch
# Epoch: 5/5.. Loss: 0.8543.. Test accuracy: 0.6861.. 0.1314 s/batch
# Epoch: 5/5.. Loss: 0.8260.. Test accuracy: 0.6775.. 0.1123 s/batch
# Epoch: 5/5.. Loss: 0.8574.. Test accuracy: 0.6898.. 0.1138 s/batch
# Epoch: 5/5.. Loss: 0.8756.. Test accuracy: 0.6703.. 0.1620 s/batch
# Epoch: 5/5.. Loss: 0.8664.. Test accuracy: 0.6830.. 0.1131 s/batch
# Epoch: 5/5.. Loss: 0.8038.. Test accuracy: 0.6916.. 0.1139 s/batch
# Epoch: 5/5.. Loss: 0.8020.. Test accuracy: 0.6664.. 0.1161 s/batch
# Epoch: 5/5.. Loss: 0.8436.. Test accuracy: 0.7025.. 0.1723 s/batch
# Epoch: 5/5.. Loss: 0.8234.. Test accuracy: 0.6709.. 0.1142 s/batch
# Epoch: 5/5.. Loss: 0.8406.. Test accuracy: 0.6812.. 0.1148 s/batch
# Epoch: 5/5.. Loss: 0.7989.. Test accuracy: 0.6811.. 0.1106 s/batch
# Epoch: 5/5.. Loss: 0.8213.. Test accuracy: 0.6738.. 0.1779 s/batch

# %% [markdown]
# Save best trained model.

# %%
## You should be familiar with how to save a pytorch model (Make sure to save the model in your Drive)
torch.save(net.state_dict(), "convnet_cifar.pth")

# %% [markdown]
# # Some visualisations and Interpretation questions
# This code allows us to look at the filters of the first layer of convolution :

# %%
def visualize_filters(layer, title='Filters'):
    filters = layer.weight.data.clone().cpu()
    filters = (filters - filters.min()) / (filters.max() - filters.min())
    grid = vutils.make_grid(filters, nrow=8, padding=2)
    plt.figure(figsize=(8,8))
    plt.imshow(grid.permute(1, 2, 0))
    plt.title(title)
    plt.axis('off')
    plt.show()

model = ConvNet() # Untrained model

fig, axes = plt.subplots(1, 2, figsize=(16, 8))

# --- Untrained filters ---
# "features[0]" is your first convolutionnal layer, you might have to change it to conv1 if it was the name you gave it to
filters_untrained = model.features[0].weight.data.clone().cpu()
filters_untrained = (filters_untrained - filters_untrained.min()) / (filters_untrained.max() - filters_untrained.min())
grid_untrained = vutils.make_grid(filters_untrained, nrow=8, padding=2)
axes[0].imshow(grid_untrained.permute(1, 2, 0))
axes[0].set_title("Block 1 - First Conv Filters (Untrained)")
axes[0].axis("off")

# --- Trained filters ---
# Same thing here
filters_trained = net.features[0].weight.data.clone().cpu()
filters_trained = (filters_trained - filters_trained.min()) / (filters_trained.max() - filters_trained.min())
grid_trained = vutils.make_grid(filters_trained, nrow=8, padding=2)
axes[1].imshow(grid_trained.permute(1, 2, 0))
axes[1].set_title("Block 1 - First Conv Filters (Trained)")
axes[1].axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# #### What do you notice about the filters after the training ? Try to fin an interpretation about it.

# %% [markdown]
# ### Activation maps
# This code snippet uses a forward hook to capture the output of the first convolutional layer of a CNN when a sample image is passed through it. The resulting activation maps show how each filter in the layer responds to different regions or features in the image.

# %%
def get_activation(model, layer, x):
    activation = {}
    def hook_fn(module, input, output):
        activation['output'] = output.detach().cpu()
    hook = layer.register_forward_hook(hook_fn)
    model(x)
    hook.remove()
    return activation['output']

data_iter = iter(trainloader)
sample_images, sample_labels = next(data_iter)
sample_img = sample_images[0].unsqueeze(0)

# Get the feature maps after the first convolution (for example)
activation = get_activation(net, net.features[0], sample_img)

# Visualize a few feature maps in RGB:
def plot_feature_maps(feature_maps, n_cols=8):
    n_features = feature_maps.shape[1]
    n_rows = (n_features + n_cols - 1) // n_cols
    plt.figure(figsize=(n_cols * 1.5, n_rows * 1.5))
    for i in range(n_features):
        plt.subplot(n_rows, n_cols, i + 1)
        # Extract the i-th feature map from the first (and only) sample in the batch
        act = feature_maps[0, i, :, :]
        # Normalize the activation map to [0, 1]
        act_norm = (act - act.min()) / (act.max() - act.min() + 1e-8)
        # Repeat the single channel 3 times to form an RGB image
        act_rgb = act_norm.unsqueeze(0).repeat(3, 1, 1)
        plt.imshow(act_rgb.permute(1, 2, 0))
        plt.axis('off')
    plt.tight_layout()
    plt.show()

plot_feature_maps(activation, n_cols=8)

# Play with the index of the chosen sample to notice more patterns and answer the question

# %% [markdown]
# ### 1. Feature Detection
# What specific features do you observe in these activation maps? Do some maps clearly highlight edges, contours, or textures? How might these features relate to the overall structure of the sample (e.g., the outline of a horse)?
#
# ---
#
# ### 2. Effect of Training
# Consider how the activations might change after training versus an untrained (random) network. What does this tell you about the learning process?
