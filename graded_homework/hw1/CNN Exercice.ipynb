# %% [markdown]
# ## Convolutional Networks
#
# We'll check out how to build a **convolutional network** to classify CIFAR10 images. By using weight sharing - multiple units with the same weights - convolutional layers are able to learn repeated patterns in your data. For example, a unit could learn the pattern for an eye, or a face, or lower level features like edges.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import time

import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
import torch.utils.data as utils
from torchvision import datasets, transforms
from torch.utils.data.sampler import SubsetRandomSampler
import matplotlib.pyplot as plt
import torchvision.utils as vutils
from torchvision.datasets import CIFAR10

# %matplotlib inline

# %%
label_names = [
    'airplane',
    'automobile',
    'bird',
    'cat',
    'deer',
    'dog',
    'frog',
    'horse',
    'ship',
    'truck'
]


def plot_images(images, cls_true, cls_pred=None):
    """
    Adapted from https://github.com/Hvass-Labs/TensorFlow-Tutorials/
    """
    fig, axes = plt.subplots(3, 3)

    for i, ax in enumerate(axes.flat):
        # plot img
        ax.imshow(images[i, :, :, :], interpolation='spline16')

        # show true & predicted classes
        cls_true_name = label_names[cls_true[i]]
        if cls_pred is None:
            xlabel = "{0} ({1})".format(cls_true_name, cls_true[i])
        else:
            cls_pred_name = label_names[cls_pred[i]]
            xlabel = "True: {0}\nPred: {1}".format(
                cls_true_name, cls_pred_name
            )
        ax.set_xlabel(xlabel)
        ax.set_xticks([])
        ax.set_yticks([])

    plt.show()

# %%
def get_train_valid_loader(data_dir='data',
                           batch_size=64,
                           augment=False,
                           random_seed=1,
                           valid_size=0.02,
                           shuffle=True,
                           show_sample=True,
                           num_workers=4,
                           pin_memory=False):
    """
    Utility function for loading and returning train and valid
    multi-process iterators over the CIFAR-10 dataset. A sample
    9x9 grid of the images can be optionally displayed.
    If using CUDA, num_workers should be set to 1 and pin_memory to True.
    Params
    ------
    - data_dir: path directory to the dataset.
    - batch_size: how many samples per batch to load.
    - augment: whether to apply the data augmentation scheme
      mentioned in the paper. Only applied on the train split.
    - random_seed: fix seed for reproducibility.
    - valid_size: percentage split of the training set used for
      the validation set. Should be a float in the range [0, 1].
    - shuffle: whether to shuffle the train/validation indices.
    - show_sample: plot 9x9 sample grid of the dataset.
    - num_workers: number of subprocesses to use when loading the dataset.
    - pin_memory: whether to copy tensors into CUDA pinned memory. Set it to
      True if using GPU.
    Returns
    -------
    - train_loader: training set iterator.
    - valid_loader: validation set iterator.
    """
    error_msg = "[!] valid_size should be in the range [0, 1]."
    assert ((valid_size >= 0) and (valid_size <= 1)), error_msg

    normalize = transforms.Normalize(
        mean=[0.4914, 0.4822, 0.4465],
        std=[0.2023, 0.1994, 0.2010],
    )

    # define transforms for validation (no augmentation)
    valid_transform = transforms.Compose([
        transforms.ToTensor(),
        normalize,
    ])

    # Define the transform for training (and data augmentation)

    train_transform = transforms.Compose([
        transforms.ToTensor(),
        normalize,
    ])

    # load the dataset
    train_dataset = datasets.CIFAR10(
        root=data_dir, train=True,
        download=True, transform=train_transform,
    )

    valid_dataset = datasets.CIFAR10(
        root=data_dir, train=True,
        download=True, transform=valid_transform,
    )

    num_train = len(train_dataset)
    indices = list(range(num_train))
    split = int(np.floor(valid_size * num_train))

    if shuffle:
        np.random.seed(random_seed)
        np.random.shuffle(indices)

    train_idx, valid_idx = indices[split:], indices[:split]
    train_sampler = SubsetRandomSampler(train_idx)
    valid_sampler = SubsetRandomSampler(valid_idx)

    train_loader = torch.utils.data.DataLoader(
        train_dataset, batch_size=batch_size, sampler=train_sampler,
        num_workers=num_workers, pin_memory=pin_memory,
    )
    valid_loader = torch.utils.data.DataLoader(
        valid_dataset, batch_size=batch_size, sampler=valid_sampler,
        num_workers=num_workers, pin_memory=pin_memory,
    )

    # visualize some images if requested
    if show_sample:
        sample_loader = torch.utils.data.DataLoader(
            train_dataset, batch_size=9, shuffle=shuffle,
            num_workers=num_workers, pin_memory=pin_memory,
        )
        data_iter = iter(sample_loader)
        images, labels = next(data_iter)
        # Unnormalize the images for display
        mean = [0.4914, 0.4822, 0.4465]
        std = [0.2023, 0.1994, 0.2010]
        unnorm_images = [unnormalize(img, mean, std) for img in images]
        X = torch.stack(unnorm_images).numpy().transpose([0, 2, 3, 1])
        plot_images(X, labels)

    return (train_loader, valid_loader)

def unnormalize(img, mean, std):
    img = img * torch.tensor(std).view(3, 1, 1) + torch.tensor(mean).view(3, 1, 1)
    return img

trainloader, valloader = get_train_valid_loader()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.9802322e-08..1.0].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.9802322e-08..1.0].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.9802322e-08..0.8784314].

# %% [markdown]
# # Convolutional Neural Network Architecture

# %% [markdown]
# Let's first talk about the overall architecture of a CNN and how each dimension evolves after each layer, we'll take as example the first and famous CNN LeNet5 :
# <figure align="center">
#   <img src="https://doimages.nyc3.cdn.digitaloceanspaces.com/010AI-ML/content/images/2021/10/image-17.png" alt="LeNet5 Architecture" width="600">
#   <figcaption>Image credit: <a href="https://en.wikipedia.org">Wikipedia</a></figcaption>
# </figure>

# %% [markdown]
# For that, we will have some quick questions to see if you understand what happens during training/inference:
#
# ### 1. First Layer Convolution
#
# If we consider the input of LeNet5 to be CIFAR-10, what would be the shape of the parameters of the first convolutional layer (stride = 1)?
#
# - **A.** `torch.Size([6, 1, 5, 5])`
# - **B.** `torch.Size([6, 3, 3, 3])`
# - **C.** `torch.Size([6, 1, 5, 5])`
# - **D.** `torch.Size([6, 3, 5, 5])`
#
# It's the response D
#
# ---
#
# ### 2. Subsampling Window
#
# What is the shape of the subsampling window (stride = 2) for the second layer (between C1 and C2), and does this shape remain invariant regardless of the subsampling method (e.g., Avg pooling or Max pooling)?
#
# - **A.** `2x2, yes it does`
# - **B.** `3x3, no it doesn't`
# - **C.** `2x2, no it doesn't`
# - **D.** `yes, it does`
#
# It's the response A
#
# ---
#
# ### 3. Backpropagation for Convolutional Filters
#
# Do the filters in the convolutional layers also benefit from backpropagation?
#
# Yes
#
# ---
#
# ### 4. Role of the Fully-Connected Layer
#
# Explain in your own words why it is necessary to have a fully-connected layer in the architecture.
#
# The CNN layer is use to extract features, so at some point we need a fully-connected layer to be able to take a decision based on these features
#
# ---
#
# If you had any struggle to answer one of theses questions, feel free to ask a TA about intuition or hints about the solution.

# %% [markdown]
# # Build your own Convolutional Neural Network Architecture

# %% [markdown]
# ## Different ways to improve the accuracy of your network :
# - Change the number of convolutions and layers (you can take inspiration from internet as you as you cite the architecture)
# - Change the optmizer / its hyperparameters
# - Add new types of layers
# - Do some data augmentation in the get_train_valid_loader function (flipped, cropped, uncentered images) cf. https://pytorch.org/vision/stable/transforms.html

# %%
class ConvNet(nn.Module):
    def __init__(self, n_input_channels=3, n_output=10):
        super().__init__()
        ################################################################################
        # TODO:                                                                        #
        # Define 2 or more different layers of the neural network                      #
        ################################################################################
        self.features = nn.Sequential(

            nn.Conv2d(n_input_channels, 32, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),

        )

        self.classifier = nn.Sequential(

            nn.Linear(128 * 4 * 4, 256),
            nn.ReLU(),
            nn.Dropout(0.5),

            nn.Linear(256, n_output)

        )
        ################################################################################
        #                              END OF YOUR CODE                                #
        ################################################################################

    def forward(self, x):
        ################################################################################
        # TODO:                                                                        #
        # Set up the forward pass that the input data will go through.                 #
        # A good activation function betweent the layers is a ReLu function.           #
        #                                                                              #
        # Note that the output of the last convolution layer should be flattened       #
        # before being inputted to the fully connected layer. We can flatten           #
        # Tensor `x` with `x.view`.                                                    #
        ################################################################################
        x = self.features(x)

        x = x.view(x.size(0), -1)

        x = self.classifier(x)
        ################################################################################
        #                              END OF YOUR CODE                                #
        ################################################################################

        return x

    def predict(self, x):
        logits = self.forward(x)
        return F.softmax(logits)

# %%
net = ConvNet()
################################################################################
# TODO:                                                                        #
# Choose an Optimizer that will be used to minimize the loss function.         #
# Choose a critera that measures the loss                                      #
################################################################################
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(net.parameters(), lr=0.0003)

epochs = 5
steps = 0
running_loss = 0
print_every = 20
for e in range(epochs):
    start = time.time()
    for images, labels in iter(trainloader):

        steps += 1
        ################################################################################
        # TODO:                                                                        #
        # Run the training process                                                     #
        #                                                                              #
        #                                                                              #
        ################################################################################
        targets = labels

        optimizer.zero_grad()

        output = net(images)
        ################################################################################
        #                              END OF YOUR CODE                                #
        ################################################################################

        loss = criterion(output, targets)
        ################################################################################
        # TODO:                                                                        #
        # Run the training process                                                     #
        #                                                                              #
        # HINT: Calculate the gradient and move one step further                       #
        ################################################################################
        loss.backward()
        optimizer.step()
        ################################################################################
        #                              END OF YOUR CODE                                #
        ################################################################################

        running_loss += loss.item()

        if steps % print_every == 0:
            stop = time.time()
            # Test accuracy
            accuracy = 0
            for ii, (images, labels) in enumerate(valloader):

                ################################################################################
                # TODO:                                                                        #
                # Calculate the accuracy                                                       #
                ################################################################################
                with torch.no_grad():

                  outputs = net(images)

                  _, preds = torch.max(outputs, 1)

                  acc = torch.mean((preds == labels).float())

                  accuracy += acc
                ################################################################################
                #                              END OF YOUR CODE                                #
                ################################################################################

            print("Epoch: {}/{}..".format(e+1, epochs),
                  "Loss: {:.4f}..".format(running_loss/print_every),
                  "Test accuracy: {:.4f}..".format(accuracy/(ii+1)),
                  "{:.4f} s/batch".format((stop - start)/print_every)
                 )
            running_loss = 0
            start = time.time()
# Out:
# Epoch: 1/5.. Loss: 2.2882.. Test accuracy: 0.1543.. 0.1401 s/batch
# Epoch: 1/5.. Loss: 2.1751.. Test accuracy: 0.2068.. 0.1190 s/batch
# Epoch: 1/5.. Loss: 2.0407.. Test accuracy: 0.2480.. 0.0892 s/batch
# Epoch: 1/5.. Loss: 1.9960.. Test accuracy: 0.2898.. 0.0903 s/batch
# Epoch: 1/5.. Loss: 1.9241.. Test accuracy: 0.3230.. 0.0888 s/batch
# Epoch: 1/5.. Loss: 1.8251.. Test accuracy: 0.3176.. 0.1244 s/batch
# Epoch: 1/5.. Loss: 1.8121.. Test accuracy: 0.3529.. 0.0944 s/batch
# Epoch: 1/5.. Loss: 1.7503.. Test accuracy: 0.3346.. 0.0880 s/batch
# Epoch: 1/5.. Loss: 1.7238.. Test accuracy: 0.3738.. 0.0892 s/batch
# Epoch: 1/5.. Loss: 1.7247.. Test accuracy: 0.3775.. 0.0888 s/batch
# Epoch: 1/5.. Loss: 1.7082.. Test accuracy: 0.3996.. 0.1252 s/batch
# Epoch: 1/5.. Loss: 1.6610.. Test accuracy: 0.3934.. 0.0888 s/batch
# Epoch: 1/5.. Loss: 1.6022.. Test accuracy: 0.4053.. 0.0895 s/batch
# Epoch: 1/5.. Loss: 1.6111.. Test accuracy: 0.4115.. 0.0863 s/batch
# Epoch: 1/5.. Loss: 1.5344.. Test accuracy: 0.4135.. 0.0887 s/batch
# Epoch: 1/5.. Loss: 1.5576.. Test accuracy: 0.4395.. 0.1243 s/batch
# Epoch: 1/5.. Loss: 1.5391.. Test accuracy: 0.4418.. 0.0875 s/batch
# Epoch: 1/5.. Loss: 1.5498.. Test accuracy: 0.4309.. 0.0869 s/batch
# Epoch: 1/5.. Loss: 1.5938.. Test accuracy: 0.4168.. 0.0900 s/batch
# Epoch: 1/5.. Loss: 1.5389.. Test accuracy: 0.4477.. 0.1034 s/batch
# Epoch: 1/5.. Loss: 1.5306.. Test accuracy: 0.4654.. 0.1216 s/batch
# Epoch: 1/5.. Loss: 1.4906.. Test accuracy: 0.4371.. 0.0892 s/batch
# Epoch: 1/5.. Loss: 1.4758.. Test accuracy: 0.4420.. 0.0890 s/batch
# Epoch: 1/5.. Loss: 1.5082.. Test accuracy: 0.4615.. 0.0883 s/batch
# Epoch: 1/5.. Loss: 1.5062.. Test accuracy: 0.4563.. 0.1200 s/batch
# Epoch: 1/5.. Loss: 1.4038.. Test accuracy: 0.4816.. 0.1050 s/batch
# Epoch: 1/5.. Loss: 1.5045.. Test accuracy: 0.4668.. 0.0912 s/batch
# Epoch: 1/5.. Loss: 1.4881.. Test accuracy: 0.4758.. 0.0896 s/batch
# Epoch: 1/5.. Loss: 1.4553.. Test accuracy: 0.4805.. 0.0891 s/batch
# Epoch: 1/5.. Loss: 1.4582.. Test accuracy: 0.4621.. 0.1282 s/batch
# Epoch: 1/5.. Loss: 1.4205.. Test accuracy: 0.5021.. 0.0929 s/batch
# Epoch: 1/5.. Loss: 1.3657.. Test accuracy: 0.4725.. 0.0930 s/batch
# Epoch: 1/5.. Loss: 1.5179.. Test accuracy: 0.4803.. 0.0941 s/batch
# Epoch: 1/5.. Loss: 1.3670.. Test accuracy: 0.5023.. 0.1042 s/batch
# Epoch: 1/5.. Loss: 1.3403.. Test accuracy: 0.4961.. 0.1191 s/batch
# Epoch: 1/5.. Loss: 1.4113.. Test accuracy: 0.5045.. 0.0920 s/batch
# Epoch: 1/5.. Loss: 1.3482.. Test accuracy: 0.5242.. 0.0916 s/batch
# Epoch: 1/5.. Loss: 1.4018.. Test accuracy: 0.5082.. 0.0940 s/batch
# Epoch: 2/5.. Loss: 1.3617.. Test accuracy: 0.5146.. 0.1166 s/batch
# Epoch: 2/5.. Loss: 1.3386.. Test accuracy: 0.5082.. 0.0920 s/batch
# Epoch: 2/5.. Loss: 1.2962.. Test accuracy: 0.5088.. 0.0905 s/batch
# Epoch: 2/5.. Loss: 1.3034.. Test accuracy: 0.5223.. 0.0919 s/batch
# Epoch: 2/5.. Loss: 1.3132.. Test accuracy: 0.5355.. 0.1053 s/batch
# Epoch: 2/5.. Loss: 1.3402.. Test accuracy: 0.5293.. 0.1213 s/batch
# Epoch: 2/5.. Loss: 1.2872.. Test accuracy: 0.5469.. 0.0907 s/batch
# Epoch: 2/5.. Loss: 1.2844.. Test accuracy: 0.5496.. 0.0925 s/batch
# Epoch: 2/5.. Loss: 1.3116.. Test accuracy: 0.5189.. 0.0976 s/batch
# Epoch: 2/5.. Loss: 1.3149.. Test accuracy: 0.5158.. 0.1408 s/batch
# Epoch: 2/5.. Loss: 1.2684.. Test accuracy: 0.5281.. 0.1022 s/batch
# Epoch: 2/5.. Loss: 1.2941.. Test accuracy: 0.5549.. 0.0984 s/batch
# Epoch: 2/5.. Loss: 1.3007.. Test accuracy: 0.5359.. 0.0967 s/batch
# Epoch: 2/5.. Loss: 1.2541.. Test accuracy: 0.5396.. 0.1111 s/batch
# Epoch: 2/5.. Loss: 1.2443.. Test accuracy: 0.5545.. 0.1310 s/batch
# Epoch: 2/5.. Loss: 1.2555.. Test accuracy: 0.5437.. 0.1003 s/batch
# Epoch: 2/5.. Loss: 1.2114.. Test accuracy: 0.5416.. 0.0983 s/batch
# Epoch: 2/5.. Loss: 1.2451.. Test accuracy: 0.5500.. 0.0972 s/batch
# Epoch: 2/5.. Loss: 1.2451.. Test accuracy: 0.5480.. 0.1348 s/batch
# Epoch: 2/5.. Loss: 1.2382.. Test accuracy: 0.5631.. 0.0951 s/batch
# Epoch: 2/5.. Loss: 1.2651.. Test accuracy: 0.5566.. 0.0987 s/batch
# Epoch: 2/5.. Loss: 1.2301.. Test accuracy: 0.5441.. 0.0941 s/batch
# Epoch: 2/5.. Loss: 1.1879.. Test accuracy: 0.5604.. 0.1172 s/batch
# Epoch: 2/5.. Loss: 1.2371.. Test accuracy: 0.5787.. 0.1286 s/batch
# Epoch: 2/5.. Loss: 1.2343.. Test accuracy: 0.5703.. 0.0987 s/batch
# Epoch: 2/5.. Loss: 1.1647.. Test accuracy: 0.5477.. 0.0952 s/batch
# Epoch: 2/5.. Loss: 1.2337.. Test accuracy: 0.5617.. 0.0954 s/batch
# Epoch: 2/5.. Loss: 1.2100.. Test accuracy: 0.5732.. 0.1374 s/batch
# Epoch: 2/5.. Loss: 1.1971.. Test accuracy: 0.5480.. 0.0936 s/batch
# Epoch: 2/5.. Loss: 1.1693.. Test accuracy: 0.5666.. 0.0955 s/batch
# Epoch: 2/5.. Loss: 1.1846.. Test accuracy: 0.5840.. 0.0955 s/batch
# Epoch: 2/5.. Loss: 1.1286.. Test accuracy: 0.5793.. 0.1223 s/batch
# Epoch: 2/5.. Loss: 1.1595.. Test accuracy: 0.5559.. 0.1211 s/batch
# Epoch: 2/5.. Loss: 1.2217.. Test accuracy: 0.5867.. 0.0940 s/batch
# Epoch: 2/5.. Loss: 1.1546.. Test accuracy: 0.5824.. 0.0933 s/batch
# Epoch: 2/5.. Loss: 1.1932.. Test accuracy: 0.5906.. 0.0962 s/batch
# Epoch: 2/5.. Loss: 1.1881.. Test accuracy: 0.5947.. 0.1373 s/batch
# Epoch: 2/5.. Loss: 1.2189.. Test accuracy: 0.5711.. 0.0966 s/batch
# Epoch: 3/5.. Loss: 1.1514.. Test accuracy: 0.5857.. 0.0525 s/batch
# Epoch: 3/5.. Loss: 1.1479.. Test accuracy: 0.5871.. 0.1053 s/batch
# Epoch: 3/5.. Loss: 1.0795.. Test accuracy: 0.5904.. 0.1401 s/batch
# Epoch: 3/5.. Loss: 1.1147.. Test accuracy: 0.5840.. 0.1155 s/batch
# Epoch: 3/5.. Loss: 1.1373.. Test accuracy: 0.5918.. 0.0998 s/batch
# Epoch: 3/5.. Loss: 1.1526.. Test accuracy: 0.5723.. 0.1023 s/batch
# Epoch: 3/5.. Loss: 1.1481.. Test accuracy: 0.5836.. 0.1236 s/batch
# Epoch: 3/5.. Loss: 1.0569.. Test accuracy: 0.5908.. 0.1266 s/batch
# Epoch: 3/5.. Loss: 1.0887.. Test accuracy: 0.5844.. 0.1021 s/batch
# Epoch: 3/5.. Loss: 1.1513.. Test accuracy: 0.6020.. 0.1011 s/batch
# Epoch: 3/5.. Loss: 1.0952.. Test accuracy: 0.5945.. 0.1113 s/batch
# Epoch: 3/5.. Loss: 1.0957.. Test accuracy: 0.5859.. 0.1369 s/batch
# Epoch: 3/5.. Loss: 1.0685.. Test accuracy: 0.6193.. 0.1041 s/batch
# Epoch: 3/5.. Loss: 1.0779.. Test accuracy: 0.6088.. 0.1051 s/batch
# Epoch: 3/5.. Loss: 1.1287.. Test accuracy: 0.5943.. 0.1022 s/batch
# Epoch: 3/5.. Loss: 1.0924.. Test accuracy: 0.6129.. 0.1441 s/batch
# Epoch: 3/5.. Loss: 1.0786.. Test accuracy: 0.6023.. 0.1077 s/batch
# Epoch: 3/5.. Loss: 1.0633.. Test accuracy: 0.6070.. 0.1033 s/batch
# Epoch: 3/5.. Loss: 1.0038.. Test accuracy: 0.6187.. 0.1068 s/batch
# Epoch: 3/5.. Loss: 1.1198.. Test accuracy: 0.6035.. 0.1489 s/batch
# Epoch: 3/5.. Loss: 1.0328.. Test accuracy: 0.6000.. 0.1026 s/batch
# Epoch: 3/5.. Loss: 1.0718.. Test accuracy: 0.6174.. 0.1050 s/batch
# Epoch: 3/5.. Loss: 1.0695.. Test accuracy: 0.6100.. 0.1038 s/batch
# Epoch: 3/5.. Loss: 0.9608.. Test accuracy: 0.6248.. 0.1489 s/batch
# Epoch: 3/5.. Loss: 1.0489.. Test accuracy: 0.6160.. 0.1071 s/batch
# Epoch: 3/5.. Loss: 1.0839.. Test accuracy: 0.6234.. 0.1078 s/batch
# Epoch: 3/5.. Loss: 1.0632.. Test accuracy: 0.6127.. 0.1086 s/batch
# Epoch: 3/5.. Loss: 1.0030.. Test accuracy: 0.6182.. 0.1542 s/batch
# Epoch: 3/5.. Loss: 1.1057.. Test accuracy: 0.6256.. 0.1184 s/batch
# Epoch: 3/5.. Loss: 1.0580.. Test accuracy: 0.6102.. 0.1123 s/batch
# Epoch: 3/5.. Loss: 1.0593.. Test accuracy: 0.6199.. 0.1109 s/batch
# Epoch: 3/5.. Loss: 0.9907.. Test accuracy: 0.6100.. 0.1513 s/batch
# Epoch: 3/5.. Loss: 1.1159.. Test accuracy: 0.6238.. 0.1091 s/batch
# Epoch: 3/5.. Loss: 1.0069.. Test accuracy: 0.6227.. 0.1048 s/batch
# Epoch: 3/5.. Loss: 1.0294.. Test accuracy: 0.6174.. 0.1029 s/batch
# Epoch: 3/5.. Loss: 1.0211.. Test accuracy: 0.6146.. 0.1348 s/batch
# Epoch: 3/5.. Loss: 0.9951.. Test accuracy: 0.6449.. 0.1196 s/batch
# Epoch: 3/5.. Loss: 0.9864.. Test accuracy: 0.6277.. 0.1060 s/batch
# Epoch: 4/5.. Loss: 0.9456.. Test accuracy: 0.6150.. 0.0245 s/batch
# Epoch: 4/5.. Loss: 1.0141.. Test accuracy: 0.6449.. 0.1278 s/batch
# Epoch: 4/5.. Loss: 0.9924.. Test accuracy: 0.6318.. 0.1262 s/batch
# Epoch: 4/5.. Loss: 1.0050.. Test accuracy: 0.6256.. 0.1046 s/batch
# Epoch: 4/5.. Loss: 0.9982.. Test accuracy: 0.6258.. 0.1081 s/batch
# Epoch: 4/5.. Loss: 1.0081.. Test accuracy: 0.6432.. 0.1283 s/batch
# Epoch: 4/5.. Loss: 0.9639.. Test accuracy: 0.6580.. 0.1326 s/batch
# Epoch: 4/5.. Loss: 1.0200.. Test accuracy: 0.6412.. 0.1059 s/batch
# Epoch: 4/5.. Loss: 0.9576.. Test accuracy: 0.6303.. 0.1046 s/batch
# Epoch: 4/5.. Loss: 0.9951.. Test accuracy: 0.6283.. 0.1079 s/batch
# Epoch: 4/5.. Loss: 0.9303.. Test accuracy: 0.6189.. 0.1565 s/batch
# Epoch: 4/5.. Loss: 0.9786.. Test accuracy: 0.6395.. 0.1084 s/batch
# Epoch: 4/5.. Loss: 0.9668.. Test accuracy: 0.6361.. 0.1039 s/batch
# Epoch: 4/5.. Loss: 1.0016.. Test accuracy: 0.6506.. 0.1029 s/batch
# Epoch: 4/5.. Loss: 0.9161.. Test accuracy: 0.6430.. 0.1558 s/batch
# Epoch: 4/5.. Loss: 0.9347.. Test accuracy: 0.6555.. 0.1061 s/batch
# Epoch: 4/5.. Loss: 0.9625.. Test accuracy: 0.6510.. 0.1070 s/batch
# Epoch: 4/5.. Loss: 0.8886.. Test accuracy: 0.6309.. 0.1050 s/batch
# Epoch: 4/5.. Loss: 0.9976.. Test accuracy: 0.6391.. 0.1541 s/batch
# Epoch: 4/5.. Loss: 1.0202.. Test accuracy: 0.6242.. 0.1091 s/batch
# Epoch: 4/5.. Loss: 0.9675.. Test accuracy: 0.6496.. 0.1045 s/batch
# Epoch: 4/5.. Loss: 0.9364.. Test accuracy: 0.6354.. 0.1061 s/batch
# Epoch: 4/5.. Loss: 0.9776.. Test accuracy: 0.6455.. 0.1506 s/batch
# Epoch: 4/5.. Loss: 0.9280.. Test accuracy: 0.6438.. 0.1004 s/batch
# Epoch: 4/5.. Loss: 0.9187.. Test accuracy: 0.6451.. 0.1027 s/batch
# Epoch: 4/5.. Loss: 0.8920.. Test accuracy: 0.6533.. 0.1024 s/batch
# Epoch: 4/5.. Loss: 0.9689.. Test accuracy: 0.6410.. 0.1381 s/batch
# Epoch: 4/5.. Loss: 0.9764.. Test accuracy: 0.6414.. 0.1209 s/batch
# Epoch: 4/5.. Loss: 0.9588.. Test accuracy: 0.6725.. 0.1059 s/batch
# Epoch: 4/5.. Loss: 0.9359.. Test accuracy: 0.6590.. 0.1035 s/batch
# Epoch: 4/5.. Loss: 0.9261.. Test accuracy: 0.6576.. 0.1288 s/batch
# Epoch: 4/5.. Loss: 0.9131.. Test accuracy: 0.6416.. 0.1314 s/batch
# Epoch: 4/5.. Loss: 0.9167.. Test accuracy: 0.6621.. 0.1051 s/batch
# Epoch: 4/5.. Loss: 0.8497.. Test accuracy: 0.6576.. 0.1055 s/batch
# Epoch: 4/5.. Loss: 0.9476.. Test accuracy: 0.6369.. 0.1199 s/batch
# Epoch: 4/5.. Loss: 0.9094.. Test accuracy: 0.6648.. 0.1351 s/batch
# Epoch: 4/5.. Loss: 0.8845.. Test accuracy: 0.6625.. 0.1083 s/batch
# Epoch: 4/5.. Loss: 0.8960.. Test accuracy: 0.6607.. 0.1059 s/batch
# Epoch: 4/5.. Loss: 0.8674.. Test accuracy: 0.6508.. 0.1128 s/batch
# Epoch: 5/5.. Loss: 0.8698.. Test accuracy: 0.6316.. 0.1391 s/batch
# Epoch: 5/5.. Loss: 0.9150.. Test accuracy: 0.6607.. 0.1057 s/batch
# Epoch: 5/5.. Loss: 0.8627.. Test accuracy: 0.6676.. 0.1053 s/batch
# Epoch: 5/5.. Loss: 0.8594.. Test accuracy: 0.6471.. 0.1165 s/batch
# Epoch: 5/5.. Loss: 0.8838.. Test accuracy: 0.6506.. 0.1435 s/batch
# Epoch: 5/5.. Loss: 0.8799.. Test accuracy: 0.6578.. 0.1094 s/batch
# Epoch: 5/5.. Loss: 0.8580.. Test accuracy: 0.6654.. 0.1092 s/batch
# Epoch: 5/5.. Loss: 0.8546.. Test accuracy: 0.6637.. 0.1180 s/batch
# Epoch: 5/5.. Loss: 0.8457.. Test accuracy: 0.6732.. 0.1491 s/batch
# Epoch: 5/5.. Loss: 0.9164.. Test accuracy: 0.6615.. 0.1068 s/batch
# Epoch: 5/5.. Loss: 0.8579.. Test accuracy: 0.6783.. 0.1068 s/batch
# Epoch: 5/5.. Loss: 0.8637.. Test accuracy: 0.6598.. 0.1060 s/batch
# Epoch: 5/5.. Loss: 0.8505.. Test accuracy: 0.6748.. 0.1531 s/batch
# Epoch: 5/5.. Loss: 0.8930.. Test accuracy: 0.6592.. 0.1071 s/batch
# Epoch: 5/5.. Loss: 0.7967.. Test accuracy: 0.6686.. 0.1075 s/batch
# Epoch: 5/5.. Loss: 0.8881.. Test accuracy: 0.6689.. 0.1098 s/batch
# Epoch: 5/5.. Loss: 0.8900.. Test accuracy: 0.6674.. 0.1555 s/batch
# Epoch: 5/5.. Loss: 0.8715.. Test accuracy: 0.6697.. 0.1061 s/batch
# Epoch: 5/5.. Loss: 0.8477.. Test accuracy: 0.6516.. 0.1071 s/batch
# Epoch: 5/5.. Loss: 0.9285.. Test accuracy: 0.6404.. 0.1058 s/batch
# Epoch: 5/5.. Loss: 0.8275.. Test accuracy: 0.6832.. 0.1503 s/batch
# Epoch: 5/5.. Loss: 0.8401.. Test accuracy: 0.6613.. 0.1076 s/batch
# Epoch: 5/5.. Loss: 0.8655.. Test accuracy: 0.6309.. 0.1063 s/batch
# Epoch: 5/5.. Loss: 0.8624.. Test accuracy: 0.6652.. 0.1056 s/batch
# Epoch: 5/5.. Loss: 0.8921.. Test accuracy: 0.6646.. 0.1455 s/batch
# Epoch: 5/5.. Loss: 0.8645.. Test accuracy: 0.6582.. 0.1052 s/batch
# Epoch: 5/5.. Loss: 0.8727.. Test accuracy: 0.6717.. 0.1031 s/batch
# Epoch: 5/5.. Loss: 0.8771.. Test accuracy: 0.6953.. 0.1035 s/batch
# Epoch: 5/5.. Loss: 0.8322.. Test accuracy: 0.6791.. 0.1485 s/batch
# Epoch: 5/5.. Loss: 0.8667.. Test accuracy: 0.6807.. 0.1055 s/batch
# Epoch: 5/5.. Loss: 0.8423.. Test accuracy: 0.6709.. 0.1064 s/batch
# Epoch: 5/5.. Loss: 0.8639.. Test accuracy: 0.6799.. 0.1070 s/batch
# Epoch: 5/5.. Loss: 0.8511.. Test accuracy: 0.6729.. 0.1448 s/batch
# Epoch: 5/5.. Loss: 0.8785.. Test accuracy: 0.6811.. 0.1120 s/batch
# Epoch: 5/5.. Loss: 0.8362.. Test accuracy: 0.6760.. 0.1051 s/batch
# Epoch: 5/5.. Loss: 0.8255.. Test accuracy: 0.6760.. 0.1039 s/batch
# Epoch: 5/5.. Loss: 0.8231.. Test accuracy: 0.6814.. 0.1331 s/batch
# Epoch: 5/5.. Loss: 0.8756.. Test accuracy: 0.6656.. 0.1270 s/batch

# %% [markdown]
# Save best trained model.

# %%
## You should be familiar with how to save a pytorch model (Make sure to save the model in your Drive)
save_path = '/content/drive/MyDrive/convnet_cifar.pth'
torch.save(net.state_dict(), save_path)

# %% [markdown]
# # Some visualisations and Interpretation questions
# This code allows us to look at the filters of the first layer of convolution :

# %%
def visualize_filters(layer, title='Filters'):
    filters = layer.weight.data.clone().cpu()
    filters = (filters - filters.min()) / (filters.max() - filters.min())
    grid = vutils.make_grid(filters, nrow=8, padding=2)
    plt.figure(figsize=(8,8))
    plt.imshow(grid.permute(1, 2, 0))
    plt.title(title)
    plt.axis('off')
    plt.show()

model = ConvNet() # Untrained model

fig, axes = plt.subplots(1, 2, figsize=(16, 8))

# --- Untrained filters ---
# "features[0]" is your first convolutionnal layer, you might have to change it to conv1 if it was the name you gave it to
filters_untrained = model.features[0].weight.data.clone().cpu()
filters_untrained = (filters_untrained - filters_untrained.min()) / (filters_untrained.max() - filters_untrained.min())
grid_untrained = vutils.make_grid(filters_untrained, nrow=8, padding=2)
axes[0].imshow(grid_untrained.permute(1, 2, 0))
axes[0].set_title("Block 1 - First Conv Filters (Untrained)")
axes[0].axis("off")

# --- Trained filters ---
# Same thing here
filters_trained = net.features[0].weight.data.clone().cpu()
filters_trained = (filters_trained - filters_trained.min()) / (filters_trained.max() - filters_trained.min())
grid_trained = vutils.make_grid(filters_trained, nrow=8, padding=2)
axes[1].imshow(grid_trained.permute(1, 2, 0))
axes[1].set_title("Block 1 - First Conv Filters (Trained)")
axes[1].axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# #### What do you notice about the filters after the training ? Try to fin an interpretation about it.

# %% [markdown]
# ### Activation maps
# This code snippet uses a forward hook to capture the output of the first convolutional layer of a CNN when a sample image is passed through it. The resulting activation maps show how each filter in the layer responds to different regions or features in the image.

# %%
def get_activation(model, layer, x):
    activation = {}
    def hook_fn(module, input, output):
        activation['output'] = output.detach().cpu()
    hook = layer.register_forward_hook(hook_fn)
    model(x)
    hook.remove()
    return activation['output']

data_iter = iter(trainloader)
sample_images, sample_labels = next(data_iter)
sample_img = sample_images[0].unsqueeze(0)

# Get the feature maps after the first convolution (for example)
activation = get_activation(net, net.features[0], sample_img)

# Visualize a few feature maps in RGB:
def plot_feature_maps(feature_maps, n_cols=8):
    n_features = feature_maps.shape[1]
    n_rows = (n_features + n_cols - 1) // n_cols
    plt.figure(figsize=(n_cols * 1.5, n_rows * 1.5))
    for i in range(n_features):
        plt.subplot(n_rows, n_cols, i + 1)
        # Extract the i-th feature map from the first (and only) sample in the batch
        act = feature_maps[0, i, :, :]
        # Normalize the activation map to [0, 1]
        act_norm = (act - act.min()) / (act.max() - act.min() + 1e-8)
        # Repeat the single channel 3 times to form an RGB image
        act_rgb = act_norm.unsqueeze(0).repeat(3, 1, 1)
        plt.imshow(act_rgb.permute(1, 2, 0))
        plt.axis('off')
    plt.tight_layout()
    plt.show()

plot_feature_maps(activation, n_cols=8)

# Play with the index of the chosen sample to notice more patterns and answer the question

# %% [markdown]
# ### 1. Feature Detection
# What specific features do you observe in these activation maps? Do some maps clearly highlight edges, contours, or textures? How might these features relate to the overall structure of the sample (e.g., the outline of a horse)?
#
# ---
#
# ### 2. Effect of Training
# Consider how the activations might change after training versus an untrained (random) network. What does this tell you about the learning process?
